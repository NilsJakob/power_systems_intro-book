# %%
# HIDE_INIT
from IPython.display import Javascript

Javascript("""
setTimeout(function() {
  document.querySelectorAll('.jp-CodeCell').forEach(cell => {
    if (cell.innerText.includes('# FEEDBACK CELL') ||
        cell.innerText.includes('# SCORE CELL')) {
      const btn = cell.querySelector('[title="Collapse Input"]');
      if (btn) btn.click();
    }
  });
}, 800);
""")

# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel $\rightarrow$ Restart) and then **run all cells** (in the menubar, select Cell $\rightarrow$ Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = ""
COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# # A2: Fundamentals of Electrical Power Systems
#
# This notebook covers:
# - MKS and SI units
# - Per-unit system
# - Time-domain signals
# - RMS values
#
# Complete the following tasks.

# %% [markdown]
# ## Task 1: MKS Units

# %%
# YOUR CODE HERE
# Assign correct SI units
voltage_unit = None
current_unit = None
power_unit = None

# %%
# FEEDBACK CELL
def _solution():
    return ('Volt','Ampere','Watt')

correct = _solution()
if (voltage_unit, current_unit, power_unit) == correct:
    print('Correct')
else:
    print('Try again')

# %% [markdown]
# ## Task 2: Per-unit

# %%
# TASK CELL

def per_unit(x, x_base):
    # YOUR CODE HERE
    return None

# %%
# FEEDBACK CELL

def _solution(x, x_base):
    return x / x_base

student = per_unit(10, 5)

if student is None:
    print("No answer yet")
elif isinstance(student, (int, float)):
    if abs(student - _solution(10, 5)) < 1e-6:
        print("Correct")
    else:
        print("Try again")
else:
    print("Invalid output")

# %% [markdown]
# ## Task 3: RMS value

# %%
# TASK CELL
import numpy as np

def compute_rms(V_hat):
    # YOUR CODE HERE
    return None

# %%
# FEEDBACK CELL

def _solution(V_hat):
    return V_hat / np.sqrt(2)

student = compute_rms(325)

if student is None:
    print("No answer yet")
elif isinstance(student, (int, float)):
    if abs(student - _solution(325)) < 1e-6:
        print("Correct")
    else:
        print("Try again")
else:
    print("Invalid output")

# %% [markdown]
# ## Task 4: Time-domain signal

# %%
# TASK CELL
import numpy as np

def voltage_signal(t, V_hat, f, theta):
    # YOUR CODE HERE
    return None

# %%
# FEEDBACK CELL

def _solution(t, V_hat, f, theta):
    omega = 2*np.pi*f
    return V_hat * np.cos(omega*t + theta)

t = np.linspace(0,0.1,100)

student = voltage_signal(t, 325, 50, 0)

if student is None:
    print("No answer yet")
elif isinstance(student, (int, float, np.ndarray)):
    if np.allclose(student, _solution(t, 325, 50, 0)):
        print("Correct")
    else:
        print("Try again")
else:
    print("Invalid output")
