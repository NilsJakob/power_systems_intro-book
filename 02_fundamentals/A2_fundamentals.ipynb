# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel $\rightarrow$ Restart) and then **run all cells** (in the menubar, select Cell $\rightarrow$ Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = ""
COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# # Assignment A2: Fundamentals of Electrical Power Systems
#
# ## Start Assignment in Binder
#
# [![Launch Binder](https://mybinder.org/badge_logo.svg)](
# https://mybinder.org/v2/gh/nilsjakob/power_systems_intro-book/main?urlpath=lab/tree/02_fundamentals/A2_fundamentals.ipynb
# )
#
# ---
#
# ## How to work on this assignment
#
# 1. Click the **Launch Binder** button above
# 2. Wait for the environment to start (30–60 seconds)
# 3. Solve the tasks
# 4. Run the test/check cells
# 5. Repeat until everything is correct
#
# This notebook covers:
# - MKS and SI units
# - Per-unit system
# - Time-domain signals
# - RMS values
#
# Complete the following tasks.

# %% [markdown]
# ## Task 1: MKS Units

# %%
# YOUR CODE HERE
# Assign correct SI units
voltage_unit = None
current_unit = None
power_unit = None

# %% [markdown]
# ## Task 2: Per-unit

# %%
# TASK CELL

def per_unit(x, x_base):
    # YOUR CODE HERE
    return None

# %% [markdown]
# ## Task 3: RMS value

# %%
# TASK CELL
import numpy as np

def compute_rms(V_hat):
    # YOUR CODE HERE
    return None

# %% [markdown]
# ## Task 4: Time-domain signal

# %%
# TASK CELL
import numpy as np

def voltage_signal(t, V_hat, f, theta):
    # YOUR CODE HERE
    return None

# %%
# FEEDBACK CELL

import numpy as np

def check(student, expected, name):
    if expected is None:
        print(f"{name}: cannot evaluate yet")
        return False
    elif student is None:
        print(f"{name}: no answer yet")
        return False
    elif isinstance(student, (int, float)):
        if abs(student - expected) < 1e-6:
            print(f"{name}: correct")
            return True
        else:
            print(f"{name}: incorrect")
            return False
    elif isinstance(student, np.ndarray):
        if np.allclose(student, expected):
            print(f"{name}: correct")
            return True
        else:
            print(f"{name}: incorrect")
            return False
    elif isinstance(student, tuple):
        if student == expected:
            print(f"{name}: correct")
            return True
        else:
            print(f"{name}: incorrect")
            return False
    else:
        print(f"{name}: invalid output")
        return False


results = []

def _solution_units():
    return ('Volt', 'Ampere', 'Watt')

student_units = (voltage_unit, current_unit, power_unit)
expected_units = _solution_units()

results.append(check(student_units, expected_units, "Q1 units"))

def _solution_per_unit(x, x_base):
    return x / x_base

student_pu = per_unit(10, 5)
expected_pu = _solution_per_unit(10, 5)

results.append(check(student_pu, expected_pu, "Q2 per_unit"))

def _solution_signal(t, V_hat, f, theta):
    omega = 2*np.pi*f
    return V_hat * np.cos(omega*t + theta)

t = np.linspace(0, 0.1, 100)
student_signal = voltage_signal(t, 325, 50, 0)
expected_signal = _solution_signal(t, 325, 50, 0)

results.append(check(student_signal, expected_signal, "Q3 voltage_signal"))



def _solution_rms(V_hat):
    return V_hat / np.sqrt(2)

student_rms = compute_rms(325)
expected_rms = _solution_rms(325)

results.append(check(student_rms, expected_rms, "Q4 RMS"))



score = sum(results)
total = len(results)

print("\n--- Summary ---")
print(f"Score: {score}/{total}")
